# %% [markdown]
# # Лабораторная работа № 7

# %% [markdown]
# В рамках этой лабораторной работы вам необходимо запустить DiT из diffusers и сгенерировать что-нибудь. Поиграйте с гиперпараметрами генерации по своему желанию.
#
# Попробуйте нарисовать елочку, например.
#
# На защите расскажите, в чем суть DiT? Какой подход используется для генерации? Как авторы модифицировали трансформер? Для чего?
#
# Считайте эту лабораторную работу менее строгим разбором [статьи](https://arxiv.org/pdf/2212.09748). Защищать ее не надо будет при условии расписанных вопросов.? Хороших праздников!
